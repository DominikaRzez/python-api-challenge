# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 609

# %%
#Performing API call to retrieve data
#printing number and name of the city while being processed
url="https://api.openweathermap.org/data/2.5/weather?"
lat=[]
lng=[]
temp=[]
humidity=[]
clouds=[]
wind=[]
country=[]
date=[]
for city in cities:
    try:
        query_url=f"{url}q={city}&units=imperial&appid={weather_api_key}"
        response = requests.get(query_url).json()
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        print(f"Processing city number {cities.index(city)+1}, name: {city}")
    except:
        lat.append(pd.NaT)
        lng.append(pd.NaT)
        temp.append(pd.NaT)
        humidity.append(pd.NaT)
        clouds.append(pd.NaT)
        wind.append(pd.NaT)
        country.append(pd.NaT)
        date.append(pd.NaT)
        print("City not found. Processing further...")
        
print("Data retrieval completed")
# Out:
# Processing city number 1, name: mataura
# Processing city number 2, name: tasiilaq
# Processing city number 3, name: chokurdakh
# Processing city number 4, name: rikitea
# Processing city number 5, name: hermanus
# Processing city number 6, name: mezen
# Processing city number 7, name: atuona
# Processing city number 8, name: shushtar
# City not found. Processing further...
# Processing city number 10, name: tuktoyaktuk
# Processing city number 11, name: qasigiannguit
# City not found. Processing further...
# Processing city number 13, name: albany
# Processing city number 14, name: souillac
# Processing city number 15, name: kodiak
# Processing city number 16, name: avera
# Processing city number 17, name: micheweni
# Processing city number 18, name: khatanga
# Processing city number 19, name: maneadero
# Processing city number 20, name: chuy
# Processing city number 21, name: kahului
# Processing city number 22, name: cabedelo
# Processing city number 23, name: yellowknife
# Processing city number 24, name: puerto ayora
# Processing city number 25, name: ushuaia
# Processing city number 26, name: busselton
# Processing city number 27, name: port elizabeth
# Processing city number 28, name: esperance
# Processing city number 29, name: torbay
# Processing city number 30, name: necochea
# Processing city number 31, name: kyshtovka
# Processing city number 32, name: kapaa
# Processing city number 33, name: sitka
# Processing city number 34, name: oranjemund
# Processing city number 35, name: loanda
# Processing city number 36, name: paracuru
# Processing city number 37, name: kagoro
# Processing city number 38, name: cape town
# City not found. Processing further...
# Processing city number 40, name: pimentel
# Processing city number 41, name: vaini
# Processing city number 42, name: bredasdorp
# Processing city number 43, name: biloela
# Processing city number 44, name: new norfolk
# Processing city number 45, name: zhigansk
# Processing city number 46, name: nome
# Processing city number 47, name: abensberg
# Processing city number 48, name: nhulunbuy
# Processing city number 49, name: westport
# Processing city number 50, name: sao gabriel
# City not found. Processing further...
# Processing city number 52, name: cherskiy
# Processing city number 53, name: excelsior springs
# City not found. Processing further...
# Processing city number 55, name: saint george
# Processing city number 56, name: iqaluit
# Processing city number 57, name: barrow
# City not found. Processing further...
# Processing city number 59, name: dikson
# City not found. Processing further...
# City not found. Processing further...
# Processing city number 62, name: namatanai
# Processing city number 63, name: leh
# Processing city number 64, name: mabaruma
# Processing city number 65, name: punta arenas
# Processing city number 66, name: siocon
# Processing city number 67, name: port alfred
# Processing city number 68, name: leningradskiy
# Processing city number 69, name: pochutla
# Processing city number 70, name: asau
# Processing city number 71, name: pucara
# Processing city number 72, name: saint-philippe
# Processing city number 73, name: knyaze-volkonskoye
# Processing city number 74, name: hasaki
# Processing city number 75, name: nikolskoye
# Processing city number 76, name: mukhen
# Processing city number 77, name: calvinia
# Processing city number 78, name: saint-pierre
# Processing city number 79, name: nanakuli
# Processing city number 80, name: carnarvon
# Processing city number 81, name: waingapu
# Processing city number 82, name: grindavik
# Processing city number 83, name: talnakh
# Processing city number 84, name: hede
# Processing city number 85, name: outjo
# Processing city number 86, name: butaritari
# Processing city number 87, name: east london
# Processing city number 88, name: ribeira grande
# Processing city number 89, name: itoman
# Processing city number 90, name: rio claro
# Processing city number 91, name: husavik
# Processing city number 92, name: chicama
# Processing city number 93, name: aklavik
# Processing city number 94, name: saint-augustin
# Processing city number 95, name: tacoronte
# City not found. Processing further...
# Processing city number 97, name: norman wells
# Processing city number 98, name: marsh harbour
# Processing city number 99, name: severo-kurilsk
# Processing city number 100, name: sao gabriel da cachoeira
# Processing city number 101, name: abha
# Processing city number 102, name: invermere
# Processing city number 103, name: darnah
# Processing city number 104, name: roma
# Processing city number 105, name: mlonggo
# Processing city number 106, name: ilebo
# Processing city number 107, name: molchanovo
# Processing city number 108, name: rocha
# Processing city number 109, name: jamestown
# Processing city number 110, name: avarua
# Processing city number 111, name: mahebourg
# Processing city number 112, name: hobart
# Processing city number 113, name: arraial do cabo
# Processing city number 114, name: yeppoon
# Processing city number 115, name: saskylakh
# City not found. Processing further...
# Processing city number 117, name: olafsvik
# Processing city number 118, name: mbaiki
# Processing city number 119, name: sumbawanga
# Processing city number 120, name: high prairie
# Processing city number 121, name: yumen
# Processing city number 122, name: dali
# Processing city number 123, name: lavrentiya
# Processing city number 124, name: rockland
# Processing city number 125, name: upernavik
# Processing city number 126, name: kaitangata
# Processing city number 127, name: padang
# Processing city number 128, name: saint-georges
# Processing city number 129, name: la rioja
# Processing city number 130, name: anadyr
# Processing city number 131, name: bluff
# Processing city number 132, name: cuiluan
# Processing city number 133, name: isangel
# Processing city number 134, name: faanui
# Processing city number 135, name: college
# Processing city number 136, name: yerofey pavlovich
# Processing city number 137, name: at-bashi
# Processing city number 138, name: kavaratti
# Processing city number 139, name: sola
# Processing city number 140, name: hofn
# Processing city number 141, name: lebu
# Processing city number 142, name: ostrovnoy
# Processing city number 143, name: geraldton
# Processing city number 144, name: mar del plata
# Processing city number 145, name: bethel
# Processing city number 146, name: qaanaaq
# City not found. Processing further...
# Processing city number 148, name: melnikovo
# Processing city number 149, name: merauke
# Processing city number 150, name: sioux lookout
# Processing city number 151, name: melita
# Processing city number 152, name: colares
# Processing city number 153, name: ambilobe
# Processing city number 154, name: cabo san lucas
# Processing city number 155, name: pisco
# Processing city number 156, name: tautira
# Processing city number 157, name: letterkenny
# Processing city number 158, name: wadi musa
# City not found. Processing further...
# Processing city number 160, name: nanortalik
# Processing city number 161, name: cam ranh
# Processing city number 162, name: paidha
# Processing city number 163, name: marfino
# Processing city number 164, name: lokosovo
# Processing city number 165, name: akdepe
# Processing city number 166, name: laguna
# Processing city number 167, name: huarmey
# Processing city number 168, name: bandarbeyla
# Processing city number 169, name: hithadhoo
# Processing city number 170, name: napier
# Processing city number 171, name: berlevag
# Processing city number 172, name: griffith
# Processing city number 173, name: the valley
# Processing city number 174, name: muros
# Processing city number 175, name: luan
# Processing city number 176, name: lalitpur
# Processing city number 177, name: charters towers
# Processing city number 178, name: touros
# Processing city number 179, name: hobyo
# Processing city number 180, name: tiksi
# Processing city number 181, name: ahipara
# Processing city number 182, name: san cristobal
# Processing city number 183, name: chifeng
# Processing city number 184, name: constitucion
# Processing city number 185, name: coroico
# Processing city number 186, name: kapit
# Processing city number 187, name: visby
# Processing city number 188, name: cidreira
# Processing city number 189, name: mbandaka
# Processing city number 190, name: saldanha
# City not found. Processing further...
# Processing city number 192, name: narsaq
# Processing city number 193, name: luwingu
# Processing city number 194, name: monforte de lemos
# Processing city number 195, name: whitley bay
# City not found. Processing further...
# Processing city number 197, name: nexo
# Processing city number 198, name: kruisfontein
# Processing city number 199, name: zaysan
# Processing city number 200, name: guhagar
# Processing city number 201, name: egvekinot
# Processing city number 202, name: clyde river
# Processing city number 203, name: somotillo
# Processing city number 204, name: petatlan
# Processing city number 205, name: airai
# Processing city number 206, name: ixtapa
# Processing city number 207, name: tupik
# Processing city number 208, name: kanakapura
# Processing city number 209, name: cairns
# Processing city number 210, name: lima
# City not found. Processing further...
# Processing city number 212, name: matara
# Processing city number 213, name: port blair
# Processing city number 214, name: tura
# Processing city number 215, name: palmer
# Processing city number 216, name: lahij
# Processing city number 217, name: xingtai
# Processing city number 218, name: kutum
# Processing city number 219, name: victoria
# Processing city number 220, name: provideniya
# Processing city number 221, name: iquique
# City not found. Processing further...
# Processing city number 223, name: sale
# Processing city number 224, name: linhares
# Processing city number 225, name: svetlogorsk
# Processing city number 226, name: ponta do sol
# City not found. Processing further...
# Processing city number 228, name: baruun-urt
# Processing city number 229, name: puerto madero
# Processing city number 230, name: sainte-agathe-des-monts
# Processing city number 231, name: salvador
# Processing city number 232, name: bilma
# Processing city number 233, name: moussoro
# Processing city number 234, name: cap malheureux
# Processing city number 235, name: roura
# Processing city number 236, name: abu samrah
# Processing city number 237, name: gold coast
# Processing city number 238, name: viedma
# Processing city number 239, name: eureka
# Processing city number 240, name: karpathos
# Processing city number 241, name: altamira
# Processing city number 242, name: iquira
# Processing city number 243, name: pitimbu
# Processing city number 244, name: ancud
# City not found. Processing further...
# Processing city number 246, name: manggar
# Processing city number 247, name: huambo
# Processing city number 248, name: hilo
# Processing city number 249, name: langsa
# Processing city number 250, name: khuzhir
# Processing city number 251, name: lobito
# Processing city number 252, name: georgetown
# Processing city number 253, name: ayan
# City not found. Processing further...
# Processing city number 255, name: ussuriysk
# Processing city number 256, name: springfield
# Processing city number 257, name: maniitsoq
# Processing city number 258, name: la ronge
# Processing city number 259, name: neiafu
# Processing city number 260, name: nishihara
# Processing city number 261, name: kingaroy
# Processing city number 262, name: pacific grove
# Processing city number 263, name: kushmurun
# Processing city number 264, name: edd
# Processing city number 265, name: verkhoyansk
# Processing city number 266, name: jhargram
# Processing city number 267, name: mount isa
# City not found. Processing further...
# Processing city number 269, name: pevek
# Processing city number 270, name: turayf
# Processing city number 271, name: puerto carreno
# Processing city number 272, name: mananjary
# Processing city number 273, name: esmeraldas
# Processing city number 274, name: marzuq
# Processing city number 275, name: baranain
# Processing city number 276, name: sinnamary
# Processing city number 277, name: riohacha
# Processing city number 278, name: kungurtug
# Processing city number 279, name: valga
# Processing city number 280, name: lumeje
# Processing city number 281, name: castro
# Processing city number 282, name: copiapo
# Processing city number 283, name: maarianhamina
# Processing city number 284, name: newport
# Processing city number 285, name: preeceville
# Processing city number 286, name: si sa ket
# Processing city number 287, name: kerema
# Processing city number 288, name: nouadhibou
# Processing city number 289, name: lagoa
# Processing city number 290, name: sebeta
# Processing city number 291, name: san lawrenz
# Processing city number 292, name: mrakovo
# Processing city number 293, name: phuket
# Processing city number 294, name: perth
# Processing city number 295, name: belonia
# Processing city number 296, name: bambous virieux
# Processing city number 297, name: pangnirtung
# Processing city number 298, name: poum
# Processing city number 299, name: edmundston
# Processing city number 300, name: flinders
# Processing city number 301, name: bengkulu
# Processing city number 302, name: mehamn
# Processing city number 303, name: jining
# Processing city number 304, name: fortuna
# Processing city number 305, name: chattanooga
# Processing city number 306, name: russell
# Processing city number 307, name: monchegorsk
# Processing city number 308, name: champerico
# Processing city number 309, name: port-gentil
# Processing city number 310, name: havre-saint-pierre
# Processing city number 311, name: svetlyy
# Processing city number 312, name: deputatskiy
# Processing city number 313, name: vila velha
# Processing city number 314, name: auki
# Processing city number 315, name: kanigiri
# Processing city number 316, name: marsabit
# Processing city number 317, name: puerto escondido
# Processing city number 318, name: seoul
# Processing city number 319, name: mandalgovi
# Processing city number 320, name: abalak
# Processing city number 321, name: batagay-alyta
# Processing city number 322, name: gizo
# Processing city number 323, name: potiskum
# Processing city number 324, name: san lazaro
# Processing city number 325, name: kavieng
# Processing city number 326, name: sao filipe
# Processing city number 327, name: koudougou
# Processing city number 328, name: halifax
# Processing city number 329, name: diffa
# Processing city number 330, name: berlin
# Processing city number 331, name: kommunar
# Processing city number 332, name: bonfim
# Processing city number 333, name: tsiroanomandidy
# Processing city number 334, name: tuatapere
# Processing city number 335, name: bongandanga
# Processing city number 336, name: lompoc
# Processing city number 337, name: axim
# Processing city number 338, name: thompson
# Processing city number 339, name: dingle
# Processing city number 340, name: portland
# Processing city number 341, name: muli
# Processing city number 342, name: juegang
# Processing city number 343, name: kapoeta
# Processing city number 344, name: ampanihy
# Processing city number 345, name: altay
# Processing city number 346, name: labuhan
# Processing city number 347, name: bara
# Processing city number 348, name: luderitz
# Processing city number 349, name: kasongo
# Processing city number 350, name: kabinda
# Processing city number 351, name: myitkyina
# Processing city number 352, name: port lincoln
# Processing city number 353, name: codrington
# Processing city number 354, name: smoky lake
# Processing city number 355, name: monrovia
# Processing city number 356, name: newala
# Processing city number 357, name: grand-santi
# Processing city number 358, name: san patricio
# Processing city number 359, name: jalingo
# Processing city number 360, name: alyangula
# Processing city number 361, name: klenovyy
# Processing city number 362, name: hamilton
# Processing city number 363, name: alice springs
# Processing city number 364, name: broome
# Processing city number 365, name: moron
# Processing city number 366, name: longyearbyen
# Processing city number 367, name: yulara
# Processing city number 368, name: urusha
# Processing city number 369, name: berck
# Processing city number 370, name: camacha
# Processing city number 371, name: taoudenni
# Processing city number 372, name: fallon
# Processing city number 373, name: toppenish
# Processing city number 374, name: manado
# City not found. Processing further...
# Processing city number 376, name: verkhnyaya sinyachikha
# Processing city number 377, name: santa maria
# Processing city number 378, name: thyolo
# Processing city number 379, name: tommot
# Processing city number 380, name: lorengau
# Processing city number 381, name: tromso
# Processing city number 382, name: bathsheba
# Processing city number 383, name: maraba
# Processing city number 384, name: novoagansk
# Processing city number 385, name: dingli
# Processing city number 386, name: arona
# Processing city number 387, name: bilibino
# Processing city number 388, name: lazarev
# Processing city number 389, name: blythe
# Processing city number 390, name: imbituba
# Processing city number 391, name: kyakhta
# Processing city number 392, name: santiago
# Processing city number 393, name: alibag
# Processing city number 394, name: buchanan
# Processing city number 395, name: orlik
# City not found. Processing further...
# City not found. Processing further...
# Processing city number 398, name: saint-francois
# Processing city number 399, name: kut chap
# Processing city number 400, name: uyar
# Processing city number 401, name: lata
# Processing city number 402, name: bago
# Processing city number 403, name: shache
# Processing city number 404, name: cayenne
# Processing city number 405, name: nabire
# Processing city number 406, name: nauta
# Processing city number 407, name: sao borja
# Processing city number 408, name: vardo
# Processing city number 409, name: weihai
# Processing city number 410, name: sheltozero
# City not found. Processing further...
# Processing city number 412, name: san quintin
# Processing city number 413, name: harnai
# Processing city number 414, name: idritsa
# Processing city number 415, name: saint anthony
# City not found. Processing further...
# City not found. Processing further...
# Processing city number 418, name: suzhou
# Processing city number 419, name: camana
# Processing city number 420, name: la union
# Processing city number 421, name: chernyshevskiy
# City not found. Processing further...
# Processing city number 423, name: havoysund
# Processing city number 424, name: aswan
# Processing city number 425, name: mundwa
# Processing city number 426, name: karwar
# Processing city number 427, name: katsuura
# Processing city number 428, name: cockburn town
# Processing city number 429, name: antalaha
# Processing city number 430, name: saint-joseph
# Processing city number 431, name: omboue
# Processing city number 432, name: tual
# Processing city number 433, name: juneau
# Processing city number 434, name: sloboda
# Processing city number 435, name: vila do maio
# Processing city number 436, name: boende
# Processing city number 437, name: kampot
# Processing city number 438, name: khandyga
# Processing city number 439, name: hambantota
# Processing city number 440, name: ures
# Processing city number 441, name: brownsville
# Processing city number 442, name: bahia blanca
# Processing city number 443, name: sungai padi
# Processing city number 444, name: petropavlovsk-kamchatskiy
# Processing city number 445, name: iskateley
# Processing city number 446, name: briancon
# Processing city number 447, name: fethiye
# Processing city number 448, name: ginir
# Processing city number 449, name: kokemaki
# Processing city number 450, name: pulaski
# Processing city number 451, name: umea
# Processing city number 452, name: marienburg
# Processing city number 453, name: manta
# Processing city number 454, name: bonthe
# Processing city number 455, name: khamgaon
# Processing city number 456, name: mogadishu
# City not found. Processing further...
# Processing city number 458, name: soure
# Processing city number 459, name: heihe
# Processing city number 460, name: devils lake
# City not found. Processing further...
# Processing city number 462, name: yarim
# Processing city number 463, name: tripoli
# Processing city number 464, name: bukama
# Processing city number 465, name: nemuro
# Processing city number 466, name: cochrane
# Processing city number 467, name: thio
# Processing city number 468, name: sao joao da barra
# Processing city number 469, name: beboto
# Processing city number 470, name: ambanja
# Processing city number 471, name: gat
# Processing city number 472, name: alofi
# Processing city number 473, name: garowe
# City not found. Processing further...
# Processing city number 475, name: kurchum
# Processing city number 476, name: byron bay
# Processing city number 477, name: verkhnyaya inta
# Processing city number 478, name: kinablangan
# Processing city number 479, name: nuuk
# Processing city number 480, name: kaeo
# Processing city number 481, name: belaya gora
# Processing city number 482, name: cherepovets
# Processing city number 483, name: ust-maya
# Processing city number 484, name: henties bay
# Processing city number 485, name: patacamaya
# Processing city number 486, name: korla
# Processing city number 487, name: chapais
# City not found. Processing further...
# Processing city number 489, name: karratha
# Processing city number 490, name: lublin
# Processing city number 491, name: west bay
# Processing city number 492, name: ketchikan
# Processing city number 493, name: hami
# Processing city number 494, name: cerknica
# Processing city number 495, name: gallup
# Processing city number 496, name: chumikan
# Processing city number 497, name: stephenville
# Processing city number 498, name: numaligarh
# Processing city number 499, name: najran
# Processing city number 500, name: tateyama
# Processing city number 501, name: puerto el triunfo
# Processing city number 502, name: san matias
# Processing city number 503, name: songkhla
# Processing city number 504, name: tonantins
# Processing city number 505, name: ostashkov
# Processing city number 506, name: nioro
# Processing city number 507, name: port keats
# Processing city number 508, name: nizhnyaya tavda
# Processing city number 509, name: bugene
# Processing city number 510, name: moree
# Processing city number 511, name: malakal
# Processing city number 512, name: trelew
# Processing city number 513, name: empalme
# Processing city number 514, name: los llanos de aridane
# Processing city number 515, name: fairbanks
# Processing city number 516, name: campbell river
# Processing city number 517, name: acapulco
# Processing city number 518, name: xuchang
# City not found. Processing further...
# Processing city number 520, name: morondava
# Processing city number 521, name: ornskoldsvik
# Processing city number 522, name: namibe
# Processing city number 523, name: manati
# Processing city number 524, name: bosansko grahovo
# Processing city number 525, name: high level
# City not found. Processing further...
# Processing city number 527, name: alanya
# Processing city number 528, name: ucluelet
# Processing city number 529, name: chegdomyn
# Processing city number 530, name: mareeba
# Processing city number 531, name: beloha
# Processing city number 532, name: ibra
# Processing city number 533, name: north bend
# Processing city number 534, name: sayat
# Processing city number 535, name: grand gaube
# Processing city number 536, name: richards bay
# Processing city number 537, name: elko
# Processing city number 538, name: maracaibo
# Processing city number 539, name: verkhnevilyuysk
# Processing city number 540, name: ust-omchug
# Processing city number 541, name: rio grande
# Processing city number 542, name: makat
# Processing city number 543, name: haimen
# Processing city number 544, name: taonan
# Processing city number 545, name: buala
# Processing city number 546, name: mount gambier
# Processing city number 547, name: vyartsilya
# Processing city number 548, name: biak
# Processing city number 549, name: baykit
# Processing city number 550, name: rawson
# City not found. Processing further...
# Processing city number 552, name: la ligua
# Processing city number 553, name: kamaishi
# Processing city number 554, name: aasiaat
# Processing city number 555, name: mayo
# Processing city number 556, name: smithers
# Processing city number 557, name: podosinovets
# Processing city number 558, name: salmo
# Processing city number 559, name: pekalongan
# Processing city number 560, name: santa barbara
# Processing city number 561, name: prince rupert
# Processing city number 562, name: ayagoz
# Processing city number 563, name: bahir dar
# Processing city number 564, name: pakokku
# Processing city number 565, name: karasburg
# Processing city number 566, name: danielskuil
# Processing city number 567, name: tucuma
# Processing city number 568, name: muscat
# Processing city number 569, name: marawi
# Processing city number 570, name: merke
# City not found. Processing further...
# City not found. Processing further...
# Processing city number 573, name: ulladulla
# Processing city number 574, name: waipawa
# City not found. Processing further...
# Processing city number 576, name: zeya
# City not found. Processing further...
# Processing city number 578, name: klaksvik
# Processing city number 579, name: ekibastuz
# Processing city number 580, name: bom jardim
# Processing city number 581, name: taraz
# Processing city number 582, name: goderich
# Processing city number 583, name: kudahuvadhoo
# Processing city number 584, name: snasa
# Processing city number 585, name: caravelas
# Processing city number 586, name: mahibadhoo
# Processing city number 587, name: puerto colombia
# Processing city number 588, name: okhotsk
# Processing city number 589, name: dabhol
# Processing city number 590, name: paungde
# Processing city number 591, name: road town
# Processing city number 592, name: laramie
# Processing city number 593, name: ilulissat
# Processing city number 594, name: hushitai
# Processing city number 595, name: williamsport
# Processing city number 596, name: victoria point
# Processing city number 597, name: kendari
# Processing city number 598, name: kijang
# Processing city number 599, name: larap
# City not found. Processing further...
# City not found. Processing further...
# City not found. Processing further...
# Processing city number 603, name: vila franca do campo
# Processing city number 604, name: nokaneng
# Processing city number 605, name: cefalu
# Processing city number 606, name: muisne
# Processing city number 607, name: gunzenhausen
# Processing city number 608, name: praya
# Processing city number 609, name: cartagena
# Data retrieval completed

# %%
#building data frame to display city data
cities_data=pd.DataFrame({"City": cities,
                         "Lat": lat,
                         "Lng": lng,
                         "Max temp": temp,
                         "Humidity": humidity,
                         "Cloudiness": clouds,
                         "Wind Speed": wind,
                         "Country": country,
                         "Date":date})
cities_data
# Out:
#              City      Lat       Lng Max temp Humidity Cloudiness Wind Speed  \
# 0         mataura -46.1927  168.8643    55.47       88        100       5.82
# 1        tasiilaq  65.6145  -37.6368    28.56       88        100      38.68
# 2      chokurdakh  70.6333  147.9167   -40.54      100         59       2.95
# 3         rikitea -23.1203 -134.9692    76.06       71         40         10
# 4        hermanus -34.4187   19.2345     63.9       90        100      17.65
# ..            ...      ...       ...      ...      ...        ...        ...
# 604        cefalu  38.0386   14.0229    57.74       73         44       5.99
# 605        muisne      0.6  -80.0333    76.15       80        100       9.93
# 606  gunzenhausen     49.1     10.75    41.86       86        100      15.01
# 607         praya  14.9215  -23.5087    73.94       78         75      20.71
# 608     cartagena  10.3997  -75.5144    83.82       74         75       9.22
#
#     Country        Date
# 0        NZ  1638655653
# 1        GL  1638655653
# 2        RU  1638655654
# 3        PF  1638655654
# 4        ZA  1638655655
# ..      ...         ...
# 604      IT  1638655850
# 605      EC  1638655850
# 606      DE  1638655850
# 607      CV  1638655850
# 608      CO  1638655851
#
# [609 rows x 9 columns]

# %%
#removing all NA rows
cleaned=cities_data.dropna(axis=0, how="any")
cleaned.head()
# Out:
#          City      Lat       Lng Max temp Humidity Cloudiness Wind Speed  \
# 0     mataura -46.1927  168.8643    55.47       88        100       5.82
# 1    tasiilaq  65.6145  -37.6368    28.56       88        100      38.68
# 2  chokurdakh  70.6333  147.9167   -40.54      100         59       2.95
# 3     rikitea -23.1203 -134.9692    76.06       71         40         10
# 4    hermanus -34.4187   19.2345     63.9       90        100      17.65
#
#   Country        Date
# 0      NZ  1638655653
# 1      GL  1638655653
# 2      RU  1638655654
# 3      PF  1638655654
# 4      ZA  1638655655

# %%
#saving raw data as csv
cleaned.to_csv("../output_data/Cities.csv")

# %%
#displaying statistical summary for the numerical columns
stats_summary=cleaned[["Lat","Lng","Max temp","Humidity","Cloudiness","Wind Speed"]].astype(float)
stats_summary=stats_summary.describe()
stats_summary
# Out:
#               Lat         Lng    Max temp    Humidity  Cloudiness  Wind Speed
# count  568.000000  568.000000  568.000000  568.000000  568.000000  568.000000
# mean    19.944173   17.324240   51.977817   73.426056   59.931338    8.239243
# std     33.080369   90.977236   29.929147   19.381208   37.715409    6.309510
# min    -54.800000 -179.166700  -42.990000   12.000000    0.000000    0.000000
# 25%     -7.103475  -64.738100   31.892500   63.000000   20.000000    3.575000
# 50%     21.361950   22.311550   62.060000   77.000000   75.000000    6.990000
# 75%     48.633325   97.430700   76.082500   88.000000   98.000000   11.500000
# max     78.218600  178.416700   93.340000  100.000000  100.000000   42.080000

# %%
#checking if there are cities with humidity greater than 100%
humidity_index=[]
for humidity in cleaned["Humidity"]:
    if humidity>100:
        humidity_index.append(index(humidity))
humidity_index
# Out:
# []

# %% [markdown]
# <h1>Plotting the data</h1>

# %% [markdown]
# <h2>Temperature (F) vs. Latitude Plot</h2>

# %%
#creating scatter plot to showcase Temperature (F) vs. Latitude
x_axis=cleaned["Lat"]
max_temp=cleaned["Max temp"]
plt.title("City Latitude vs Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.scatter(x_axis, max_temp, marker="o",facecolors="red",edgecolors="black",alpha=0.75)
plt.savefig("../output_data/Latitude_vs_temp.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The plot is analysing the correlation between the latitude and the maximum temperature in the cities. The temperature is displayed in Farenheit.

# %% [markdown]
# ------------------------------------------------------------------------------------

# %% [markdown]
# <h2>Humidity (%) vs. Latitude Plot</h2>

# %%
#creating scatter plot to showcase Humidity (%) vs. Latitude
x_axis=cleaned["Lat"]
humidity_pct=cleaned["Humidity"]
plt.title("City Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.scatter(x_axis, humidity_pct, marker="o",facecolors="red",edgecolors="black",alpha=0.75)
plt.savefig("../output_data/Latitude_vs_humidity.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The plot is analysing the correlation between the latitude and the percentage of humidity in the cities.

# %% [markdown]
# ---------------------------------------------------------------------------

# %% [markdown]
# <h2>Cloudiness (%) vs. Latitude Plot</h2>

# %%
#creating scatter plot to showcase Cloudiness (%) vs. Latitude
x_axis=cleaned["Lat"]
cloudiness_pct=cleaned["Cloudiness"]
plt.title("City Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.scatter(x_axis, cloudiness_pct, marker="o",facecolors="red",edgecolors="black",alpha=0.75)
plt.savefig("../output_data/Latitude_vs_cloudiness.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The plot is analysing the correlation between the latitude and the percentage of cloudiness in the cities.

# %% [markdown]
# ------------------------------------------------------------------------------------

# %% [markdown]
# <h2>Wind Speed (mph) vs. Latitude Plot</h2>

# %%
#creating scatter plot to showcase Wind Speed (mph) vs. Latitude
x_axis=cleaned["Lat"]
wind_speed=cleaned["Wind Speed"]
plt.title("City Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.scatter(x_axis, wind_speed, marker="o",facecolors="red",edgecolors="black",alpha=0.75)
plt.savefig("../output_data/Latitude_vs_wind_speed.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The plot is analysing the correlation between the latitude and the wind speed in the cities. The speed of the wind is displayed in miles per hour.

# %% [markdown]
# --------------------------------------------------------------------

# %% [markdown]
# <h1>Linear Regression</h1>

# %%
#spliting the data frame into northern and southern depending on the latitude
northern=cleaned.loc[cleaned["Lat"]>=0,:]
southern=cleaned.loc[cleaned["Lat"]<0,:]

# %% [markdown]
# <h2>Temperature (F) vs. Latitude Plot</h2>

# %% [markdown]
# <h3>Northern Hemisphere</h3>

# %%
#plotting
x_axis=northern["Lat"]
max_temp=northern["Max temp"]
plt.title("Northern Hemisphere - Temperature (F) vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
# Performing a linear regression 
(slope, intercept,rvalue,pvalue,stderr) = linregress(x_axis.astype(float), max_temp.astype(float)) 
regress_values=x_axis*slope+intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, max_temp, marker="o",facecolors="red",edgecolors="black",alpha=0.75)
plt.plot(x_axis,regress_values,"b-")
plt.annotate(line_eq,(0,-40),fontsize=15,color="blue")
print(f"The r-squared is: {rvalue**2}")
plt.savefig("../output_data/northern_Latitude_vs_max_temp.png")
plt.show
# Out:
# The r-squared is: 0.7537375134837127
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <h3>Southern Hemisphere</h3>

# %%
#plotting
x_axis=southern["Lat"]
max_temp=southern["Max temp"]
plt.title("Southern Hemisphere - Temperature (F) vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
# Performing a linear regression 
(slope, intercept,rvalue,pvalue,stderr) = linregress(x_axis.astype(float), max_temp.astype(float)) 
regress_values=x_axis*slope+intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, max_temp, marker="o",facecolors="red",edgecolors="black",alpha=0.75)
plt.plot(x_axis,regress_values,"b-")
plt.annotate(line_eq,(-50,40),fontsize=15,color="blue")
print(f"The r-squared is: {rvalue**2}")
plt.savefig("../output_data/southern_Latitude_vs_max_temp.png")
plt.show
# Out:
# The r-squared is: 0.28707886269810823
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <h1>COMMENT</H1>

# %% [markdown]
# <H2>Humidity (%) vs. Latitude</h2>

# %% [markdown]
# <h3>Northern Hemisphere</h3>

# %%
#plotting
x_axis=northern["Lat"]
humidity=northern["Humidity"]
plt.title("Northern Hemisphere - Humidity(%) vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
# Performing a linear regression 
(slope, intercept,rvalue,pvalue,stderr) = linregress(x_axis.astype(float), humidity.astype(float)) 
regress_values=x_axis*slope+intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, humidity, marker="o",facecolors="red",edgecolors="black",alpha=0.75)
plt.plot(x_axis,regress_values,"b-")
plt.annotate(line_eq,(45,20),fontsize=15,color="blue")
print(f"The r-squared is: {rvalue**2}")
plt.savefig("../output_data/northern_Latitude_vs_humidity.png")
plt.show
# Out:
# The r-squared is: 0.09636031072247367
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <h3> Southern Hemisphere</h3>

# %%
#plotting
x_axis=southern["Lat"]
humidity=southern["Humidity"]
plt.title("Southern Hemisphere - Humidity(%) vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
# Performing a linear regression 
(slope, intercept,rvalue,pvalue,stderr) = linregress(x_axis.astype(float), humidity.astype(float)) 
regress_values=x_axis*slope+intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, humidity, marker="o",facecolors="red",edgecolors="black",alpha=0.75)
plt.plot(x_axis,regress_values,"b-")
plt.annotate(line_eq,(-23,40),fontsize=15,color="blue")
print(f"The r-squared is: {rvalue**2}")
plt.savefig("../output_data/southern_Latitude_vs_humidity.png")
plt.show
# Out:
# The r-squared is: 0.12248746888650267
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <h1>COMMENTS</h1>

# %% [markdown]
# <h2>Cloudiness (%) vs. Latitude</h2>

# %% [markdown]
# <h3> Northern Hemisphere</h3>

# %%
#plotting
x_axis=northern["Lat"]
cloudiness=northern["Cloudiness"]
plt.title("Northern Hemisphere - Cloudiness(%) vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
# Performing a linear regression 
(slope, intercept,rvalue,pvalue,stderr) = linregress(x_axis.astype(float), cloudiness.astype(float)) 
regress_values=x_axis*slope+intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, cloudiness, marker="o",facecolors="red",edgecolors="black",alpha=0.75)
plt.plot(x_axis,regress_values,"b-")
plt.annotate(line_eq,(45,20),fontsize=15,color="blue")
print(f"The r-squared is: {rvalue**2}")
plt.savefig("../output_data/northern_Latitude_vs_cloudiness.png")
plt.show
# Out:
# The r-squared is: 0.06342526638593506
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <h3>Southern Hemisphere</h3>

# %%
#plotting
x_axis=southern["Lat"]
cloudiness=southern["Cloudiness"]
plt.title("Southern Hemisphere - Cloudiness(%) vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
# Performing a linear regression 
(slope, intercept,rvalue,pvalue,stderr) = linregress(x_axis.astype(float), cloudiness.astype(float)) 
regress_values=x_axis*slope+intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, cloudiness, marker="o",facecolors="red",edgecolors="black",alpha=0.75)
plt.plot(x_axis,regress_values,"b-")
plt.annotate(line_eq,(-55,65),fontsize=15,color="blue")
print(f"The r-squared is: {rvalue**2}")
plt.savefig("../output_data/southern_Latitude_vs_cloudiness.png")
plt.show
# Out:
# The r-squared is: 0.05152032563283237
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <h1>COMMENTS</h1>

# %% [markdown]
# <h2>Wind Speed (mph) vs. Latitude</h2>

# %% [markdown]
# <h3>Northern Hemisphere</h3>

# %%
#plotting
x_axis=northern["Lat"]
wind_speed=northern["Wind Speed"]
plt.title("Northern Hemisphere - Wind Speed(mph) vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
# Performing a linear regression 
(slope, intercept,rvalue,pvalue,stderr) = linregress(x_axis.astype(float), wind_speed.astype(float)) 
regress_values=x_axis*slope+intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, wind_speed, marker="o",facecolors="red",edgecolors="black",alpha=0.75)
plt.plot(x_axis,regress_values,"b-")
plt.annotate(line_eq,(0,30),fontsize=15,color="blue")
print(f"The r-squared is: {rvalue**2}")
plt.savefig("../output_data/northern_Latitude_vs_wind_speed.png")
plt.show
# Out:
# The r-squared is: 0.020212630556082033
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <h3>Southern Hemisphere</h3>

# %%
#plotting
x_axis=southern["Lat"]
wind_speed=southern["Wind Speed"]
plt.title("Southern Hemisphere - Wind Speed(mph) vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
# Performing a linear regression 
(slope, intercept,rvalue,pvalue,stderr) = linregress(x_axis.astype(float), wind_speed.astype(float)) 
regress_values=x_axis*slope+intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, wind_speed, marker="o",facecolors="red",edgecolors="black",alpha=0.75)
plt.plot(x_axis,regress_values,"b-")
plt.annotate(line_eq,(-25,25),fontsize=15,color="blue")
print(f"The r-squared is: {rvalue**2}")
plt.savefig("../output_data/southern_Latitude_vs_wind_speed.png")
plt.show
# Out:
# The r-squared is: 0.11978196357834212
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <h1>COMMENTS</h1>
